# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio

pio.renderers.default = 'iframe'

# %%
df = pd.read_csv('coastal_news_clean.csv')

# %%
df.tail(20)
# Out:
#                                             headlines publication_date  \
# 66  City of CT urged to revisit sewage outfall dec...       2015-06-22
# 67  First on EWN:  Cape Town's sewage debacle not ...       2015-06-22
# 68                      Full moon sets off rough seas       2015-04-04
# 69                   Sea robots combat climate change       2014-12-01
# 70                     Selso the seal visits SA again       2014-11-24
# 71  Worries fish farm could make triathletes a sha...       2014-11-04
# 72             Humpback whale freed in St Francis Bay       2014-09-16
# 73           Beached whale rescued of Plettenberg Bay       2015-12-12
# 74        NSRI warns of rip currents and spring tides       2015-12-07
# 75        Operation Phakisa to transform Durban docks       2016-05-02
# 76                   Red tide confirmed on West Coast       2015-02-04
# 77     West Coast lobster numbers decrease alarmingly       2015-06-08
# 78       Sardines make surprise appearance at Margate       2015-06-05
# 79          Sea level rise poses risk to KZN property       2015-10-31
# 80           SA Weather warns of huge waves in E Cape       2015-06-04
# 81              Robot to test health of ocean 'lungs'       2014-06-13
# 82                       Buoy genius clears the coast       2015-11-20
# 83                     SA gung ho about mining oceans       2015-07-03
# 84           Ocean View fishers drowned out by policy       2015-02-10
# 85           CSIR’s SeaFAR detects massive bilge dump              NaN
#
#                                                   url  \
# 66  http://ewn.co.za/2015/06/22/City-urged-to-revi...
# 67  http://ewn.co.za/2015/06/22/First-on-EWN-CTs-s...
# 68  http://ewn.co.za/2015/04/04/Full-moon-sets-off...
# 69  https://www.enca.com/technology/sa-sea-robots-...
# 70  https://www.enca.com/life/selso-seal-visits-sa...
# 71  https://www.enca.com/south-africa/worries-fish...
# 72  https://www.enca.com/humpcak-whale-freed-st-fr...
# 73  https://www.enca.com/south-africa/beached-whal...
# 74  https://www.enca.com/south-africa/nsri-warns-r...
# 75  https://www.enca.com/south-africa/operation-ph...
# 76  http://www.sabc.co.za/news/a/8c5cdb00472f272da...
# 77  http://www.sabc.co.za/news/a/30c20a8048ac5eb48...
# 78  http://www.sabc.co.za/news/a/446df60048a21d5c9...
# 79  http://www.sabc.co.za/news/a/fc2f8c804a689db58...
# 80  http://www.sabc.co.za/news/a/fb03b180489f9b26b...
# 81  http://mg.co.za/article/2014-06-12-robot-to-te...
# 82  http://mg.co.za/article/2015-11-19-buoy-genius...
# 83  http://mg.co.za/article/2015-07-02-sa-gung-ho-...
# 84  http://mg.co.za/article/2015-02-10-the-ocean-v...
# 85  http://www.csir.co.za/news/2016/06/Bilge_dump....
#
#                                              location  \
# 66                                    Cape Town coast
# 67                                    Cape Town coast
# 68                            South African coastline
# 69                                  Cape Town's coast
# 70                         Cape Recife nature reserve
# 71                     2.5 kilometres off Hobie Beach
# 72                                     St Francis Bay
# 73                                    Plettenberg Bay
# 74                            South African coastline
# 75                    Hibberdene. KwaZulu-Natal coast
# 76  West Coast, St. Helena Bay to Doringbaai, Elan...
# 77                                       South Africa
# 78                                            Margate
# 79                                             Durban
# 80     Eastern Cape (Port Elizabeth, Plettenberg Bay)
# 81                                          Cape Town
# 82                                          False Bay
# 83                                       South Africa
# 84                                         Ocean View
# 85                  Between Madagascar and Mozambique
#
#                        event_date         category  \
# 66                            NaN            waste
# 67                            NaN            waste
# 68  2015-04-04 00:00:00.000000000    natural event
# 69  2014-12-01 00:00:00.000000000      development
# 70  2014-11-22 00:00:00.000000000         sea life
# 71  2014-11-04 00:00:00.000000000      development
# 72  2014-09-15 00:00:00.000000000            waste
# 73  2015-12-11 00:00:00.000000000            waste
# 74  2015-12-07 00:00:00.000000000         red tide
# 75  2016-05-02 00:00:00.000000000      development
# 76  2015-02-04 00:00:00.000000000         red tide
# 77  2015-06-08 00:00:00.000000000  illegal fishing
# 78                            NaN         sea life
# 79  2015-10-31 00:00:00.000000000    natural event
# 80  2015-06-04 00:00:00.000000000    natural event
# 81  2014-06-13 00:00:00.000000000      development
# 82  1970-01-01 00:00:00.000002015      development
# 83  2015-07-03 00:00:00.000000000      development
# 84  2015-02-10 00:00:00.000000000   public concern
# 85  2016-06-01 00:00:00.000000000      development
#
#                             date
# 66 2015-06-22 00:00:00.000000000
# 67 2015-06-22 00:00:00.000000000
# 68 2015-04-04 00:00:00.000000000
# 69 2014-12-01 00:00:00.000000000
# 70 2014-11-22 00:00:00.000000000
# 71 2014-11-04 00:00:00.000000000
# 72 2014-09-15 00:00:00.000000000
# 73 2015-12-11 00:00:00.000000000
# 74 2015-12-07 00:00:00.000000000
# 75 2016-05-02 00:00:00.000000000
# 76 2015-02-04 00:00:00.000000000
# 77 2015-06-08 00:00:00.000000000
# 78 2015-06-05 00:00:00.000000000
# 79 2015-10-31 00:00:00.000000000
# 80 2015-06-04 00:00:00.000000000
# 81 2014-06-13 00:00:00.000000000
# 82 1970-01-01 00:00:00.000002015
# 83 2015-07-03 00:00:00.000000000
# 84 2015-02-10 00:00:00.000000000
# 85 2016-06-01 00:00:00.000000000

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce')

# %%
df = df[df['date'] >= '2000-01-01']

# %%
# Group by date and category, count articles
timeline_data = df.groupby([df['date'].dt.to_period('M'), 'category']).size().reset_index(name='count')

# Convert period back to timestamp for plotting
timeline_data['date'] = timeline_data['date'].dt.to_timestamp()

# %%
fig = px.bar(timeline_data,
              x='date',
              y='count',
             color='category',
              title='Articles over time by category',
              labels={'date': 'Date', 'count': 'Number of Articles', 'category': 'Category'})

fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_49.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
