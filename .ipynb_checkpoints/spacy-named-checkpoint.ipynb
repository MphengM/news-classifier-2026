# %%
import csv, os, sys, spacy,string

# %%
nlp = spacy.load('en_core_web_sm')

#path = '../'
#os.chdir(path)

# %%
def tokens_to_root(token):
    """
    Walk up the syntactic tree, collecting tokens to the root of the given `token`.
    :param token: Spacy token
    :return: list of Spacy tokens
    """
    tokens_to_r = []
    while token.head is not token:
        tokens_to_r.append(token)
        token = token.head
        tokens_to_r.append(token)

    return tokens_to_r

from nltk import Tree

def to_nltk_tree(node):
    if node.n_lefts + node.n_rights >= 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_

# %%
os.getcwd()
# Out:
# '/home/mpheng/Documents/DataAnalysis/coastal_newswatch_v1'

# %%
#path = 'static/articles'
#os.chdir(path)
import pandas as pd

csvfile = csv.reader(open('coastal_news_clean.csv', 'rb'))
rows = [r for r in csvfile]

locations = []
doc = rows[3][1].decode('utf8')
text = nlp(doc)
entities = list(text.ents)
locations = [entity.orth_ for entity in entities if entity.label_ in ['GPE']]
pd.DataFrame(locations)
print(doc)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 9
#       6 rows = [r for r in csvfile]
#       8 locations = []
# ----> 9 doc = rows[3][1].decode('utf8')
#      10 text = nlp(doc)
#      11 entities = list(text.ents)
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
for ent in text.ents:
    print(ent, ent.label_, ent.root.n_rights)
    #if ent.label_=='GPE' or ent.label_=='LOC':
        #print('{}-{}'.format(ent, ent.root.head.dep_))
     #   print(ent, ent.root.n_rights)
# Out:
# (Cape Town - Members, u'PERSON', 1)
# (the City of Cape Town’s Marine, u'GPE', 1)
# (five, u'CARDINAL', 0)
# (West Coast, u'LOC', 0)
# (The City’s Mayoral Committee Member for Safety and Security, u'ORG', 2)
# (JP Smith, u'ORG', 0)
# (two, u'CARDINAL', 0)
# (Table Mountain National Parks, u'ORG', 0)
# (Cape Point, u'GPE', 2)
# (Witsand, u'GPE', 0)
# (Monday, u'DATE', 0)
# (Olifantsbos, u'GPE', 0)
# (the Cape Point, u'ORG', 0)
# (Table Mountain National Park, u'FAC', 0)
# (West Coast, u'LOC', 0)
# (Wednesday, u'DATE', 0)
# (138, u'CARDINAL', 0)
# (five, u'CARDINAL', 0)
# (Ocean View, u'GPE', 0)
# (the Simon’s Town, u'ORG', 0)
# (Three, u'CARDINAL', 1)
# (Stikland, u'FAC', 2)
# (Bellville South, u'PERSON', 0)
# (three weeks ago, u'DATE', 0)
# (three, u'CARDINAL', 1)
# (Smith, u'PERSON', 0)
# (the Department of Agriculture, u'ORG', 3)
# (Forestry, u'GPE', 2)
# (South African, u'NORP', 0)
# (Table Mountain National Parks, u'ORG', 0)
# (the Marine Living Resources Act, u'ORG', 2)
# (The City’s Mayoral Committee, u'GPE', 0)
# (Energy, Environmental and Spatial Planning, u'ORG', 2)
# (Johan van der Merwe, u'PERSON', 0)
# (150, u'CARDINAL', 0)

# %%
# Out:
# Dwarskersbos

# %%
i = 0
while i<50:
    doc = rows[i][1].decode('utf8')
    text = nlp(doc)
    for ent in text.ents:
        if ent.label_=='GPE' or ent.label_=='LOC' or ent.label_=='FAC':
             if str(ent.root.head) in ['near', 'in', 'at','Bay','bay','harbour','Harbour']:
                    if ent.root.head.dep_=='prep':
                        print(i, ent.root.head, ent, ent.label_)
            
        
        
            #print('{} - {}'.format(ent, ent.root.head))
            #if str(ent.root.head) in ['near', 'at', 'in']:
             #   print(ent.root.head, ent)

    i+=1
# Out:
# (0, at, the Umgeni River Mouth, u'FAC')
# (1, in, the Southern Ocean, u'LOC')
# (3, near, Olifantsbos, u'GPE')
# (3, at, Stikland, u'FAC')
# (4, at, Elands Bay, u'LOC')
# (4, in, Elands Bay, u'GPE')
# (5, near, Langebaan, u'GPE')
# (6, in, Eland’s Bay, u'LOC')
# (9, in, Hibberdene, u'GPE')
# (9, in, Hibberdene, u'GPE')
# (10, in, Indian Ocean, u'LOC')
# (12, in, Knysna, u'GPE')
# (14, in, Hangberg, u'GPE')
# (14, in, South Africa, u'GPE')
# (14, in, Hangberg, u'GPE')
# (14, in, Hout Bay, u'GPE')
# (14, in, the Far East, u'LOC')
# (14, near, Cape Point, u'FAC')
# (14, in, South Africa, u'GPE')
# (14, in, Hangberg, u'GPE')
# (14, in, Hangberg, u'GPE')
# (14, in, Hangberg, u'GPE')
# (15, in, Antarctica, u'LOC')
# (15, in, Antarctica, u'LOC')
# (16, in, St Francis Bay, u'LOC')
# (18, in, Ocean View, u'LOC')
# (18, in, Cape, u'GPE')
# (18, in, Ocean View, u'GPE')
# (18, in, Ocean View, u'LOC')
# (18, in, Ocean View, u'GPE')
# (18, in, Ocean View, u'GPE')
# (18, in, Ocean View, u'GPE')
# (18, in, Stompneus Bay, u'LOC')
# (19, in, Germany, u'GPE')
# (19, in, South Africa, u'GPE')
# (20, in, Southern Africa, u'LOC')
# (20, in, Southern Africa, u'LOC')
# (20, in, Durban, u'GPE')
# (20, in, Durban Government, u'GPE')
# (24, at, South Coast, u'LOC')
# (24, in, East London, u'LOC')
# (24, in, South Africa, u'GPE')
# (24, in, South Africa, u'GPE')
# (25, in, Germany, u'GPE')
# (25, in, South Africa, u'GPE')
# (27, in, South Africa, u'GPE')
# (27, in, New York, u'GPE')
# (27, in, US, u'GPE')
# (27, in, Cape Town harbour, u'GPE')
# (27, in, South Africa, u'GPE')
# (27, in, US, u'GPE')
# (27, in, Cape Town harbour, u'FAC')
# (27, in, South Africa, u'GPE')
# (27, in, New York, u'GPE')
# (28, in, Cape Town, u'GPE')
# (28, in, Cape Town, u'FAC')
# (29, at, Kommetjie, u'GPE')
# (30, in, South Africa, u'GPE')
# (31, in, South Africa, u'GPE')
# (31, in, New York, u'GPE')
# (31, in, South Africa, u'GPE')
# (31, in, Cape Town harbour, u'FAC')
# (31, in, South Africa, u'GPE')
# (34, in, Elands Bay, u'GPE')
# (35, near, Caledon, u'GPE')
# (35, in, Caledon, u'GPE')
# (36, in, Hangberg, u'GPE')
# (36, in, South Africa, u'GPE')
# (36, in, Hangberg, u'GPE')
# (36, in, Kleinmond, u'GPE')
# (36, in, Cape Town, u'GPE')
# (37, at, Elands Bay, u'FAC')
# (37, in, Elands Bay, u'GPE')
# (38, in, the Eastern Cape, u'LOC')
# (40, in, South Africa, u'GPE')
# (42, in, Northern Cape, u'LOC')
# (43, in, Melkbosstrand, u'GPE')
# (43, in, South Africa, u'GPE')
# (43, in, Paarl, u'GPE')
# (47, in, East London, u'GPE')
# (47, in, Simons-town, u'GPE')
# (47, in, Durban, u'GPE')
# (48, at, Elands Bay, u'LOC')

# %%
#testfile = csv.reader(open('locator/articles-locations.csv', 'rb'))
#row = [r for r in testfile]
i=0
while i<len(rows):
    doc = rows[i][3]
    text = nlp(doc)
    for ent in text.ents:
        print(i, ent, ent.label_)
    i+=1
# Out:
# 1 Eastern Cape LOC
# 2 Umgeni River Mouth LOC
# 2 the Blue Lagoon FAC
# 2 Durban ORG
# 3 Umgeni River Mouth LOC
# 3 the Blue Lagoon FAC
# 3 Durban ORG
# 4 KwaZulu-Natal South Coast ORG
# 4 Seaforth Beach GPE
# 4 Simon’s Town PERSON
# 5 South Africa GPE
# 6 South Africa GPE
# 7 South Africa GPE
# 8 East London GPE
# 9 East London GPE
# 10 South African NORP
# 10 Port Edward GPE
# 10 the Eastern Cape LOC
# 12 Gordon ORG
# 16 Eastern Cape LOC
# 18 Durban ORG
# 18 Port St Johns PERSON
# 19 Port Elizabeth GPE
# 21 South Africa GPE
# 25 Dassen Island GPE
# 26 South Africa GPE
# 28 Cape Point LOC
# 28 Table Mountain National Park ORG
# 29 Elands Bay FAC
# 30 Elands Bay FAC
# 31 Durban ORG
# 32 Eland GPE
# 33 Eland GPE
# 34 Plettenberg Bay PERSON
# 34 Wilderness ORG
# 35 Eland GPE
# 38 Port Elizabeth GPE
# 39 South Africa GPE
# 40 the Eastern Cape LOC
# 40 the Indian Ocean LOC
# 41 Port Elizabeth GPE
# 42 South Africa GPE
# 43 Plettenberg Bay PERSON
# 43 Wilderness ORG
# 44 Garden Route ORG
# 46 Jeffreys Bay LOC
# 47 South African NORP
# 51 Caledon ORG
# 52 Gansbaai ORG
# 54 Belville GPE
# 56 Philippi GPE
# 57 South African NORP
# 58 Algoa Bay ORG
# 58 Mossel Bay FAC
# 59 Melkbosstrand ORG
# 59 Malmesbury PERSON
# 59 Saron PERSON
# 59 Tulbagh PERSON
# 61 East London GPE
# 64 Simon PERSON
# 64 Town PRODUCT
# 65 South African NORP
# 66 Cape Town LOC
# 67 Cape Town LOC
# 68 Cape Town LOC
# 69 South African NORP
# 70 Cape Town's LOC
# 71 Cape Recife LOC
# 72 2.5 kilometres QUANTITY
# 72 Hobie Beach GPE
# 73 St Francis Bay PERSON
# 74 Plettenberg Bay PERSON
# 75 South African NORP
# 76 Hibberdene PERSON
# 76 KwaZulu-Natal ORG
# 77 West Coast LOC
# 77 St. Helena Bay to FAC
# 78 South Africa GPE
# 80 Durban ORG
# 81 Eastern Cape LOC
# 81 Port Elizabeth GPE
# 81 Plettenberg Bay PERSON
# 83 False Bay PERSON
# 84 South Africa GPE
# 85 Ocean View FAC
# 86 Mozambique ORG

# %%
from nltk import Tree

def to_nltk_tree(node):
    if node.n_lefts + node.n_rights > 0:
        return Tree(node.orth_, [to_nltk_tree(child) for child in node.children])
    else:
        return node.orth_


[to_nltk_tree(sent.root).pretty_print() for sent in text.sents]
# Out:
#      Between
#         |
#     Madagascar
#   ______|__________
# and            Mozambique
# [None]

# %%
'''csvfile = csv.reader(open('articles.csv', 'rb'))
rows = [r for r in csvfile]

locations = []
doc = rows[3][1].decode('ascii', 'ignore')
decoded = doc.decode('utf8')
text = nlp(decoded)
#entities = list(text.ents)
#locations = [entity.orth_ for entity in entities if entity.label_ in ['GPE']]
#pd.DataFrame(locations)
for token in doc:
    print(dir(token))

'''
# Out:
# "csvfile = csv.reader(open('articles.csv', 'rb'))\nrows = [r for r in csvfile]\n\nlocations = []\ndoc = rows[3][1].decode('ascii', 'ignore')\ndecoded = doc.decode('utf8')\ntext = nlp(decoded)\n#entities = list(text.ents)\n#locations = [entity.orth_ for entity in entities if entity.label_ in ['GPE']]\n#pd.DataFrame(locations)\nfor token in doc:\n    print(dir(token))\n\n"
